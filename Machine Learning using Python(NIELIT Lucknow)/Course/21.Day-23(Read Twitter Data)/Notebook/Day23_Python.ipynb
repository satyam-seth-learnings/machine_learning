# %%
#This command will install tweepy module into your computer
pip install tweepy

# %%
import tweepy
import pandas as pd

# %%
#Authorization to consumer key and consumer secret key

# Synatx: auth=tweepy.OAuthHandler(Consumer key, consumer Secret Key)

auth=tweepy.OAuthHandler("8OlZOVSa5rRpN16C6RuO9KJl2", "aLzVL7MtO5PfKdNH6CB2X0Q7HGGefFbjkTKf0IWj2eWOk9wK0e")

# Syntax: auth.set_access_token( Access Key, Access Secret Key)

auth.set_access_token( "104131500-J5oVlDuyMLBdgLf4ffGUqxqcsFOqJwcCITO3zelN", "smu3uvH1E458Oan3axnuOW7f0QHLk5ZrIRQzRuPT5e67r")

api=tweepy.API(auth)

#this function gets 20 tweets of a particular user for ex: narendramodi
tweets=api.user_timeline(screen_name="HRDMinistry")

tmp=[]
for t in tweets:
    j=[t.text,t.created_at]
    tmp.append(j)

df=pd.DataFrame(tmp,columns=["Text","Date_Time"])
df.to_csv("Day23_Output.csv")

# %%
tweets[0]

# %%
#Authorization to consumer key and consumer secret key

# Synatx: auth=tweepy.OAuthHandler(Consumer key, consumer Secret Key)

auth=tweepy.OAuthHandler("8OlZOVSa5rRpN16C6RuO9KJl2", "aLzVL7MtO5PfKdNH6CB2X0Q7HGGefFbjkTKf0IWj2eWOk9wK0e")

# Syntax: auth.set_access_token( Access Key, Access Secret Key)

auth.set_access_token( "104131500-J5oVlDuyMLBdgLf4ffGUqxqcsFOqJwcCITO3zelN", "smu3uvH1E458Oan3axnuOW7f0QHLk5ZrIRQzRuPT5e67r")

api=tweepy.API(auth)
tmp=[]

#this function gets 20 tweets of a particular user for ex: narendramodi
for i in range(1,6):
    tweets=api.user_timeline(screen_name="HRDMinistry",page=i)


    for t in tweets:
        j=[t.text,t.created_at]
        tmp.append(j)

df=pd.DataFrame(tmp,columns=["Text","Date_Time"])
df.to_csv("Day23_Output1.csv")

# %%
#Authorization to consumer key and consumer secret key

# Synatx: auth=tweepy.OAuthHandler(Consumer key, consumer Secret Key)

auth=tweepy.OAuthHandler("8OlZOVSa5rRpN16C6RuO9KJl2", "aLzVL7MtO5PfKdNH6CB2X0Q7HGGefFbjkTKf0IWj2eWOk9wK0e")

# Syntax: auth.set_access_token( Access Key, Access Secret Key)

auth.set_access_token( "104131500-J5oVlDuyMLBdgLf4ffGUqxqcsFOqJwcCITO3zelN", "smu3uvH1E458Oan3axnuOW7f0QHLk5ZrIRQzRuPT5e67r")

api=tweepy.API(auth,wait_on_rate_limit=True)
tmp=[]

for t in tweepy.Cursor(api.search,q="#nepal",count=100,since="2020-07-07").items():
    j=[t.text,t.created_at]
    tmp.append(j)

df=pd.DataFrame(tmp,columns=["Text","Date_Time"])
df.to_csv("Day23_Output2.csv")

# %%
#Authorization to consumer key and consumer secret key

# Synatx: auth=tweepy.OAuthHandler(Consumer key, consumer Secret Key)

auth=tweepy.OAuthHandler("8OlZOVSa5rRpN16C6RuO9KJl2", "aLzVL7MtO5PfKdNH6CB2X0Q7HGGefFbjkTKf0IWj2eWOk9wK0e")

# Syntax: auth.set_access_token( Access Key, Access Secret Key)

auth.set_access_token( "104131500-J5oVlDuyMLBdgLf4ffGUqxqcsFOqJwcCITO3zelN", "smu3uvH1E458Oan3axnuOW7f0QHLk5ZrIRQzRuPT5e67r")

api=tweepy.API(auth)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# #NALCO: 35-36 bouncing from monthly support
#
# daily chart : broken out  support comes at 31
#
# Disc-:taken at 32 .5 https://t.co/tUTocPAMh0
# #Axisbank 454 😍😍😍 is sustains 450 can shoot up to 460-469 ... strong momentum https://t.co/RLhoeQuNZy
# @insharebazaar ji &amp; @CAPratik_INDIAN ji
#
# Discuss with @TraderHarneet ji
#
# I know Harneet ji hold from these levels
# Nifty fut- Chances f consolidation / 200 points correction in a couple f days
# HSCL- Short term tgt 70++++
# SAIL- short term tgt 45-52. Nalco-Short term tgt 45-60
# #Canbk 113.45 😍😍😍😍🚀🚀🚀🚀 booking out partially https://t.co/wv5bIdueco
# 775+
#
# #COROMANDEL
#
# Still hold in my trading portfolio
#
# 10% move done.
#
# 👇 https://t.co/GNFyvgWvkh
# #BANDHANBANK cmp @390
#
# stock from @150 to Now @398    one sided rally...
#
# Best level to SHORT with @400 sl
#
# risky… https://t.co/viWdMfgWn9
# New post in LEARN TRADE &amp; RISK MGMT: Sunpharma 486 trading
#
# Close 50% trade
#
# ...
